# %%
import sys, torch
sys.path.insert(0, "deepseek3")                      # match the architecture of the checkpoint
from model import TinyDeepSeek
from tokenizer import CharTokenizer

# %%
ckpt = torch.load("deepseek3/tiny_deepseek.pt", map_location="cpu", weights_only=False)
tok = CharTokenizer(ckpt["chars"])
model = TinyDeepSeek(ckpt["cfg"]); model.load_state_dict(ckpt["model"]); model.eval()

model
# Out:
# TinyDeepSeek(
#   (embed_tokens): Embedding(30, 32)
#   (layers): ModuleList(
#     (0): TransformerBlock(
#       (input_layernorm): RMSNorm()
#       (attn): MLA(
#         (q_down): Linear(in_features=32, out_features=16, bias=False)
#         (q_norm): RMSNorm()
#         (q_up): Linear(in_features=16, out_features=48, bias=False)
#         (kv_down): Linear(in_features=32, out_features=8, bias=False)
#         (kv_norm): RMSNorm()
#         (kv_up): Linear(in_features=8, out_features=64, bias=False)
#         (k_rope_proj): Linear(in_features=32, out_features=4, bias=False)
#         (o_proj): Linear(in_features=32, out_features=32, bias=False)
#       )
#       (post_attention_layernorm): RMSNorm()
#       (mlp): MLP(
#         (gate_proj): Linear(in_features=32, out_features=64, bias=False)
#         (up_proj): Linear(in_features=32, out_features=64, bias=False)
#         (down_proj): Linear(in_features=64, out_features=32, bias=False)
#       )
#     )
#     (1-2): 2 x TransformerBlock(
#       (input_layernorm): RMSNorm()
#       (attn): MLA(
#         (q_down): Linear(in_features=32, out_features=16, bias=False)
#         (q_norm): RMSNorm()
#         (q_up): Linear(in_features=16, out_features=48, bias=False)
#         (kv_down): Linear(in_features=32, out_features=8, bias=False)
#         (kv_norm): RMSNorm()
#         (kv_up): Linear(in_features=8, out_features=64, bias=False)
#         (k_rope_proj): Linear(in_features=32, out_features=4, bias=False)
#         (o_proj): Linear(in_features=32, out_features=32, bias=False)
#       )
#       (post_attention_layernorm): RMSNorm()
#       (mlp): MoE(
#         (router): Linear(in_features=32, out_features=4, bias=False)
#         (experts): ModuleList(
#           (0-3): 4 x MLP(
#             (gate_proj): Linear(in_features=32, out_features=32, bias=False)
#             (up_proj): Linear(in_features=32, out_features=32, bias=False)
#             (down_proj): Linear(in_features=32, out_features=32, bias=False)
#           )
#         )
#         (shared_expert): MLP(
#           (gate_proj): Linear(in_features=32, out_features=32, bias=False)
#           (up_proj): Linear(in_features=32, out_features=32, bias=False)
#           (down_proj): Linear(in_features=32, out_features=32, bias=False)
#         )
#       )
#     )
#   )
#   (norm): RMSNorm()
#   (lm_head): Linear(in_features=32, out_features=30, bias=False)
# )

# %%
start = torch.full((10, 1), tok.eos_id, dtype=torch.long)   # every name starts at EOS/newline
out = model.generate(start, max_new_tokens=model.cfg.max_seq_len,
                     temperature=0.8, eos_id=tok.eos_id)     # stops each row at EOS
out
# Out:
# tensor([[ 0,  2, 26,  7, 29, 17,  1,  0,  0],
#         [ 0, 24,  5, 19,  9, 14,  0,  0,  0],
#         [ 0,  4,  5, 21,  1, 12,  0,  0,  0],
#         [ 0, 25, 23,  8,  1, 14,  0,  0,  0],
#         [ 0,  9, 17,  7, 26, 12,  0,  0,  0],
#         [ 0, 13,  9,  5, 12,  9,  8,  0,  0],
#         [ 0,  8,  1,  0,  0,  0,  0,  0,  0],
#         [ 0, 25, 23,  7, 26, 12,  0,  0,  0],
#         [ 0, 18,  5,  4,  1, 19,  0,  0,  0],
#         [ 0,  1, 12, 16,  5, 17,  5, 14,  0]])

# %%
for row in out.tolist():
    print(tok.decode(row[1:]).split("\n")[0])
# Out:
# bügşra
# çetin
# deval
# özhan
# irgül
# mielih
# ha
# özgül
# sedat
# alperen
